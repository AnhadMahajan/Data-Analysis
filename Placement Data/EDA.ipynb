# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline

# %%
df=pd.read_csv('college_student_placement_dataset.csv')
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
df.tail()
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 9995                    No                       1                     8
# 9996                    No                       0                     7
# 9997                   Yes                       3                     9
# 9998                    No                       7                     5
# 9999                    No                       3                     5
#
#       Projects_Completed Placement
# 9995                   0       Yes
# 9996                   2        No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  object
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  object
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#                  IQ  Prev_Sem_Result          CGPA  Academic_Performance  \
# count  10000.000000     10000.000000  10000.000000          10000.000000
# mean      99.471800         7.535673      7.532379              5.546400
# std       15.053101         1.447519      1.470141              2.873477
# min       41.000000         5.000000      4.540000              1.000000
# 25%       89.000000         6.290000      6.290000              3.000000
# 50%       99.000000         7.560000      7.550000              6.000000
# 75%      110.000000         8.790000      8.770000              8.000000
# max      158.000000        10.000000     10.460000             10.000000
#
#        Extra_Curricular_Score  Communication_Skills  Projects_Completed
# count            10000.000000          10000.000000        10000.000000
# mean                 4.970900              5.561800            2.513400
# std                  3.160103              2.900866            1.715959
# ...

# %%
df.isnull().sum()
# Out:
# College_ID                0
# IQ                        0
# Prev_Sem_Result           0
# CGPA                      0
# Academic_Performance      0
# Internship_Experience     0
# Extra_Curricular_Score    0
# Communication_Skills      0
# Projects_Completed        0
# Placement                 0
# dtype: int64

# %%
df['CGPA'].unique()
# Out:
# array([ 6.28,  5.37,  5.83,  5.75,  7.69,  5.32,  6.58,  8.76,  6.33,
#         8.6 ,  8.9 ,  6.51,  9.01,  8.4 ,  7.31,  5.8 ,  7.54, 10.01,
#         8.15,  5.56,  8.07,  7.11,  8.22,  9.17,  7.86,  9.45,  8.86,
#         8.48,  5.33,  9.61,  9.58,  6.1 ,  7.02,  9.11,  5.97,  9.27,
#         5.96,  6.98,  6.39,  5.51,  5.89,  8.72,  8.16,  5.16,  5.14,
#         5.11,  5.18,  7.89,  5.5 ,  9.56,  9.38,  8.7 ,  9.96,  8.91,
#         8.73,  7.65,  6.17,  6.06,  6.3 ,  8.1 ,  5.58,  6.53,  6.87,
#         6.22,  7.61,  9.12,  8.5 ,  7.51,  7.6 ,  6.04,  9.44,  6.16,
#         5.85,  5.78,  6.69,  5.41,  6.11,  5.57,  8.77,  9.39,  7.12,
#         9.85,  6.76,  5.99,  8.52,  7.48,  8.41,  9.26,  7.77,  9.19,
#         6.54,  6.74,  8.54,  7.96,  6.31,  7.7 ,  7.5 ,  9.57,  9.07,
#         7.62,  8.23,  9.09,  5.44,  5.88, 10.37,  7.46,  7.23,  8.87,
#         9.6 ,  7.42, 10.17,  6.92,  8.66,  6.96,  7.3 ,  5.59,  5.45,
# ...

# %%
df.head(2)
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Academic_Performance',y='Projects_Completed',data=df)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(x='Academic_Performance',y='Projects_Completed',data=df)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Extra_Curricular_Score',y='Academic_Performance',data=df)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.displot(x='Extra_Curricular_Score',y='CGPA',data=df)
plt.show()

# %%
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
plt.figure(figsize=(8, 5))
sns.boxenplot(x='Extra_Curricular_Score',y='CGPA',data=df)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='Extra_Curricular_Score',y='CGPA',data=df)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Extra_Curricular_Score', y='CGPA', data=df)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x='Extra_Curricular_Score',y='CGPA',data=df)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.swarmplot(x='Extra_Curricular_Score',y='CGPA',data=df)
plt.show()
# Out:
# c:\Users\amanm\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 68.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\amanm\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 66.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\amanm\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 66.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\amanm\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 68.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(8, 5))
sns.stripplot(x='Extra_Curricular_Score',y='CGPA',data=df)
plt.show()

# %%
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
plt.figure(figsize=(21,20))
sns.boxenplot(x='IQ',y='CGPA',data=df)
plt.show()

# %%
plt.figure(figsize=(21,20))
sns.catplot(x='IQ',y='CGPA',data=df)
plt.show()

# %%
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap="coolwarm", annot_kws={"size":10})
plt.show()

# %%
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
numeric_df.corr()
# Out:
#                               IQ  Prev_Sem_Result      CGPA  \
# IQ                      1.000000        -0.002640 -0.002859
# Prev_Sem_Result        -0.002640         1.000000  0.980768
# CGPA                   -0.002859         0.980768  1.000000
# Academic_Performance   -0.006827        -0.005765 -0.002958
# Extra_Curricular_Score -0.003458         0.009326  0.011441
# Communication_Skills   -0.010896        -0.017269 -0.018242
# Projects_Completed      0.014538         0.018434  0.020872
#
#                         Academic_Performance  Extra_Curricular_Score  \
# IQ                                 -0.006827               -0.003458
# Prev_Sem_Result                    -0.005765                0.009326
# CGPA                               -0.002958                0.011441
# Academic_Performance                1.000000                0.011774
# Extra_Curricular_Score              0.011774                1.000000
# ...

# %%
plt.figure(figsize=(10, 8))
sns.jointplot(
    x='Academic_Performance',
    y='Projects_Completed',
    data=df,
    kind='scatter',
    hue='Placement',
    palette='Set1',
    alpha=0.6
)
sns.kdeplot(
    x=df['Academic_Performance'],
    y=df['Projects_Completed'],
    levels=5,
    color='k',
    linewidths=1,
    alpha=0.5
)
plt.show()
